# %%
# !pip install beautifulsoup4 -q
# !pip install -q accelerate -U
# !pip install transformers==4.31.0 -q
# !pip install -q bitsandbytes==0.40.2
# !pip install unstructured -q

! pip install "unstructured[all-docs]" pillow pydantic lxml pillow matplotlib chromadb tiktoken -q
# !pip install unstructured[local-inference] -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 68.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 9.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 397.5/397.5 kB 42.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.1/275.1 kB 26.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 51.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 29.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.4/502.4 kB 2.9 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade langchain   -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 19.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 6.4 MB/s eta 0:00:00

# %%
url = "http://jalammar.github.io/illustrated-stable-diffusion/"

# %%
import requests
from bs4 import BeautifulSoup

# %%
def save_webpage_as_html(url, output_file):
    try:
        # Send a GET request to the URL
        response = requests.get(url)

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            # Save the HTML content to the specified file
            with open(output_file, 'w', encoding='utf-8') as file:
                file.write(response.text)
            print(f"Webpage content saved to {output_file}")
        else:
            print(f"Error: Unable to retrieve the webpage. Status code: {response.status_code}")

    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage:
url_to_convert = "http://jalammar.github.io/illustrated-stable-diffusion/"
output_html_file = "output.html"

save_webpage_as_html(url_to_convert, output_html_file)
# Out:
# Webpage content saved to output.html

# %%
from langchain.document_loaders import BSHTMLLoader
loader = BSHTMLLoader('/content/output.html',open_encoding = "utf-8" )
data = loader.load()
data
# Out:
# [Document(page_content='\n\nThe Illustrated Stable Diffusion – Jay Alammar – Visualizing machine learning one concept at a time.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nJay Alammar\nVisualizing machine learning one concept at a time.@JayAlammar on Twitter. YouTube Channel\n\n\nBlog\nAbout\n\n\n\n\n\n\nThe Illustrated Stable Diffusion\n\nTranslations: Chinese, Vietnamese.\n\n(V2 Nov 2022: Updated images for more precise description of forward diffusion. A few more images in this version)\nAI image generation is the most recent AI capability blowing people’s minds (mine included). The ability to create striking visuals from text descriptions has a magical quality to it and points clearly to a shift in how humans create art. The release of Stable Diffusion is a clear milestone in this development because it made a high-performance model available to the masses (performance in terms of image quality, as well as speed and relatively low resource/memory r
# ...

# %%
data[0].page_content=data[0].page_content.replace("\n","")

# %%
data
# Out:
# [Document(page_content='The Illustrated Stable Diffusion – Jay Alammar – Visualizing machine learning one concept at a time.Jay AlammarVisualizing machine learning one concept at a time.@JayAlammar on Twitter. YouTube ChannelBlogAboutThe Illustrated Stable DiffusionTranslations: Chinese, Vietnamese.(V2 Nov 2022: Updated images for more precise description of forward diffusion. A few more images in this version)AI image generation is the most recent AI capability blowing people’s minds (mine included). The ability to create striking visuals from text descriptions has a magical quality to it and points clearly to a shift in how humans create art. The release of Stable Diffusion is a clear milestone in this development because it made a high-performance model available to the masses (performance in terms of image quality, as well as speed and relatively low resource/memory requirements).After experimenting with AI image generation, you may start to wonder how it works.This is a gentle i
# ...

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

def split_docs(documents,chunk_size=1000,chunk_overlap=20):
  text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
  docs = text_splitter.split_documents(documents)
  return docs

docs = split_docs(data)
print(len(docs))
print(type(docs[0]))
# Out:
# 17
# <class 'langchain_core.documents.base.Document'>

# %%
import torch
from torch import cuda, bfloat16
import transformers

model_id = 'meta-llama/Llama-2-13b-chat-hf'

device = f'cuda:{cuda.current_device()}' if cuda.is_available() else 'cpu'

# set quantization configuration to load large model with less GPU memory
# this requires the `bitsandbytes` library
bnb_config = transformers.BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type='nf4',
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=bfloat16
)

# begin initializing HF items, need auth token for these
hf_auth = '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'
model_config = transformers.AutoConfig.from_pretrained(
    model_id,
    use_auth_token=hf_auth
)

model = transformers.AutoModelForCausalLM.from_pretrained(
    model_id,
    trust_remote_code=True,
    config=model_config,
    quantization_config=bnb_config,
    device_map= {"": 0},
    use_auth_token=hf_auth
)
model.eval()
print(f"Model loaded on {device}")
# Out:
# config.json:   0%|          | 0.00/587 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:2193: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# model.safetensors.index.json:   0%|          | 0.00/33.4k [00:00<?, ?B/s]
# ...
# model-00001-of-00003.safetensors:   0%|          | 0.00/9.95G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/9.90G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/6.18G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# Model loaded on cuda:0

# %%
tokenizer = transformers.AutoTokenizer.from_pretrained(
    model_id,
    use_auth_token=hf_auth
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1714: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
generate_text = transformers.pipeline(
    model=model, tokenizer=tokenizer,
    return_full_text=True,  # langchain expects the full text
    task='text-generation',
    # we pass model parameters here too
    temperature=0.1,  # 'randomness' of outputs, 0.0 is the min and 1.0 the max
    max_new_tokens=512,  # mex number of tokens to generate in the output
    repetition_penalty=1.1  # without this output begins repeating
)
# Out:
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %%
from langchain.llms import HuggingFacePipeline

llm = HuggingFacePipeline(pipeline=generate_text)

# %%
content = docs[0].page_content

template=f"<s>[INST]Generate 2 questions and answers from the context provided{content}. questions should not be more than 50 words. Amswers should not be more than 150 words Give some tags for question and answers such that I can use regex to make them into csv[/INST]"

# %%
gen_text=llm(template)

# %%
print(gen_text)
# Out:
#   Sure! Here are two questions and answers based on the context provided:
#
# Question 1: What is The Transformer, and how does it differ from other deep learning models?
#
# Answer: The Transformer is a type of deep learning model that uses attention to improve the speed of training. It was proposed in the paper "Attention is All You Need" and has been shown to outperform other models in specific tasks. Unlike other models, The Transformer is designed to be parallelizable, making it well-suited for large-scale training on cloud platforms like Google Cloud TPU.
#
# Question 2: What is the main benefit of using The Transformer over other deep learning models?
#
# ...

# %%
import re
import csv
pattern = r"(Question \d+):\s*(.*?)\s*Answer\s*:\s*(.*?)(\n\n|$)"

# Find the first match
matches = re.findall(pattern, gen_text, re.DOTALL)

questions = []
answers = []
# Access captured groups
for match in matches:
    question_number, question_text, answer_text ,space = match
    questions.append(question_text)
    answers.append(answer_text)

# %%
import pandas as pd
df = pd.DataFrame(list(zip(questions, answers)), columns = ['question', 'answer'])

# Save the DataFrame to a CSV file
df.to_csv("qa.csv", index=False)

# %%
import pandas as pd
import re

questions = []
answers = []

def generation_question_answer_pair_from_url(llm,docs):
  for i in range(0, len(docs)):
    content = docs[i].page_content
    template=f"""<s>[INST]Generate 2 questions and answers from the context provided{content}. questions should not be more than 50 words.
    Amswers should not be more than 150 words Give some tags for question and answers such that I can use regex to make them into csv[/INST]"""
    gen_text = llm(template)
    pattern = r"(Question \d+):\s*(.*?)\s*Answer\s*:\s*(.*?)(\n\n|$)"
    matches = re.findall(pattern, gen_text, re.DOTALL)
    for match in matches:
      question_number, question_text, answer_text ,space = match
      questions.append(question_text)
      answers.append(answer_text)
  return [questions,answers]

pairs = generation_question_answer_pair_from_url(llm,docs)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1083: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1083: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1083: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1083: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# ...

# %%
df = pd.DataFrame(list(zip(questions, answers)), columns = ['questions', 'answers'])

# %%
df.to_csv("qa1.csv", index=False)
